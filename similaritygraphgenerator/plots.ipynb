# %%
from classes.plots import Plots

name = "340-8_?-0.1-3-0-1_10-60-2-60-4-1_0-1-1-1-1"

plots = Plots(name)

# %%
plots.plot('exports', 'line', 'matrix_noise', 'ARI', save=True)

# %%
plots.plot('exports', 'line', 'matrix_noise', 'NMI', save=True)

# %%
plots.plot('exports', 'line', 'matrix_noise', 'AMI', save=True)

# %%
plots.plot('exports', 'line', 'matrix_noise', 'FMI', save=True)
