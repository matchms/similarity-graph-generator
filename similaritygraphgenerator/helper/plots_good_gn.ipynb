# %%
from classes.plots import Plots
plots = Plots("")

# %% [markdown]
# # Good GN

# %%
gn_good_recipe_nn_nn = "128-4_0-0-0-?-0_0-0-0-0-0-0_1-1-1-1-1"
plots.update_name(gn_good_recipe_nn_nn)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Homogeneity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Completeness', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Community Size Score', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'ARI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'NMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'AMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'FMI', save=True)

gn_good_recipe_nn_n = "128-4_0-0-0-?-1_0-0-0-0-0-0_1-1-1-1-1"
plots.update_name(gn_good_recipe_nn_n)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Homogeneity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Completeness', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Community Size Score', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'ARI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'NMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'AMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'FMI', save=True)

gn_good_recipe_n1_nn = "128-4_100-0.1-3-?-0_0-0-0-0-0-0_1-1-1-1-1"
plots.update_name(gn_good_recipe_n1_nn)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Homogeneity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Completeness', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Community Size Score', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'ARI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'NMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'AMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'FMI', save=True)

gn_good_recipe_n1_n = "128-4_100-0.1-3-?-1_0-0-0-0-0-0_1-1-1-1-1"
plots.update_name(gn_good_recipe_n1_n)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Homogeneity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Completeness', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Community Size Score', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'ARI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'NMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'AMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'FMI', save=True)

gn_good_recipe_n5_nn = "128-4_100-0.5-3-?-0_0-0-0-0-0-0_1-1-1-1-1"
plots.update_name(gn_good_recipe_n5_nn)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Homogeneity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Completeness', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Community Size Score', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'ARI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'NMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'AMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'FMI', save=True)

gn_good_recipe_n5_n = "128-4_100-0.5-3-?-1_0-0-0-0-0-0_1-1-1-1-1"
plots.update_name(gn_good_recipe_n5_n)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Homogeneity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Completeness', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Community Size Score', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'ARI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'NMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'AMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'FMI', save=True)

gn_good_recipe_n9_nn = "128-4_100-0.9-3-?-0_0-0-0-0-0-0_1-1-1-1-1"
plots.update_name(gn_good_recipe_n9_nn)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Homogeneity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Completeness', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Community Size Score', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'ARI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'NMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'AMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'FMI', save=True)

gn_good_recipe_n9_n = "128-4_100-0.9-3-?-1_0-0-0-0-0-0_1-1-1-1-1"
plots.update_name(gn_good_recipe_n9_n)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Homogeneity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Completeness', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Community Size Score', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'Modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'ARI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'NMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'AMI', save=True)
plots.plot('generated-data/gn_good_recipe', 'line', 'matrix_threshold', 'FMI', save=True)

heatmap = "128-4_100-0.?-3-?-0_0-0-0-0-0-0_1-1-1-1-1"
plots.update_name(heatmap)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Homogeneity', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Completeness', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Community Size Score', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Modularity', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'ARI', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'NMI', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'AMI', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'FMI', 'louvain', save=True)

plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Homogeneity', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Completeness', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Community Size Score', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Modularity', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'ARI', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'NMI', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'AMI', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'FMI', 'lpa', save=True)

plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Homogeneity', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Completeness', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Community Size Score', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Modularity', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'ARI', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'NMI', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'AMI', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'FMI', 'infomap', save=True)

plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Homogeneity', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Completeness', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Community Size Score', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Modularity', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'ARI', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'NMI', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'AMI', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'FMI', 'greedy_modularity', save=True)

heatmap = "128-4_100-0.?-3-?-1_0-0-0-0-0-0_1-1-1-1-1"
plots.update_name(heatmap)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Homogeneity', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Completeness', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Community Size Score', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Modularity', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'ARI', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'NMI', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'AMI', 'louvain', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'FMI', 'louvain', save=True)

plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Homogeneity', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Completeness', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Community Size Score', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Modularity', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'ARI', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'NMI', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'AMI', 'lpa', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'FMI', 'lpa', save=True)

plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Homogeneity', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Completeness', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Community Size Score', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Modularity', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'ARI', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'NMI', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'AMI', 'infomap', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'FMI', 'infomap', save=True)

plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Homogeneity', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Completeness', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Community Size Score', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'Modularity', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'ARI', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'NMI', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'AMI', 'greedy_modularity', save=True)
plots.plot('generated-data/gn_good_recipe', 'heatmap', 'matrix_threshold', 'matrix_noise_level', 'FMI', 'greedy_modularity', save=True)
