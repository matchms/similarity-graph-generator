# %%
from similaritygraphgenerator.classes.plots import Plots
plots = Plots("")

# %% [markdown]
# # Bad GN

# %%
gn_bad_recipe_nn_nn = "128-4_0-0-0-?-0_0-0-0-0-0-0_0-1-1-1-1"
plots.update_name(gn_bad_recipe_nn_nn)
plots.plot('exports/gn_recipe_bad', 'line', 'matrix_threshold', 'NMI', save=False)
